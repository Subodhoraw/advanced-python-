# %% [markdown]
# Use Case:
# A retail analytics team needs to generate specific visualizations to analyze sales across different dimensions: products, time, categories, and customer behavior. These plots are required for dashboard inclusion and must meet specific formatting standards to ensure consistency and clarity.
#
#
# Problem Description:
# Create specific types of plots based on given data using Matplotlib. Each visualization must match defined criteria including titles, axis labels, tick formatting, grid visibility, and plot type.
#
# You must implement plotting code that generates the following:
#
# A line plot titled "Product Sales - v3":
#
# X-axis shows Product IDs [1, 2, 3, 4] labeled as ['Product 1', 'Product 2', 'Product 3', 'Product 4']
#
# Y-axis labeled "Quantity Sold" with values [10, 20, 25, 10]
#
# Gridlines visible on both axes
#
# Data
#
# product_id = [1,2,3,4]
#
# quantity_sold = [10,20,25,10]
#
# image
#
# A line plot titled "Monthly Sales Comparison - v2":
#
# X-axis shows months ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
#
# Y-axis labeled "Sales ($)"
#
# Plots three products with distinct colors, markers, and line styles
#
# Legends visible
#
# Data
#
# months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
#
# product_A = [10000, 12000, 13000, 12500, 14000, 15000]
#
# product_B = [8000, 9500, 10500, 10200, 11000, 12000]
#
# product_C = [6000, 7200, 8000, 8200, 8800, 9500]
#
# image
#
# A bar plot titled "Product Sales by Category":
#
# X-axis shows product categories like ['Electronics', 'Clothing', 'Furniture', 'Toys', 'Books']
#
# Y-axis labeled "Sales ($)"
#
# Bar heights correspond to sales figures
#
# Data
#
# categories = ["Electronics", "Clothing", "Furniture", "Toys", "Books"]
#
# sales = [50000, 30000, 40000, 20000, 10000]
#
# image
#
# A histogram titled "Distribution of Student Exam Scores":
#
# X-axis shows score ranges (e.g., bins of 10 from 10 to 100)
#
# Y-axis shows number of students per range
#
# Grid visible on the Y-axis with dashed lines
#
# Plot format must remain correct regardless of data
#
# Data: scores = np.random.randint(40, 100, 50) (50 students with scores between 40-100)
#
# image
#
# A scatter plot titled "House Size vs. Price":
#
# X-axis labeled "House Size (sq ft)"
#
# Y-axis labeled "Price ($)"
#
# Dots plotted using house size and corresponding price arrays
#
# Plot must be structurally correct regardless of exact data values
#
# Data Points:
#
# house_size = np.random.randint(800, 3500, 50) → House sizes in square feet
#
# house_price = house_size * np.random.uniform(100, 300) → Prices based on size
#
# image
#
#
# Notes:
# All plots must use matplotlib.pyplot.
#
# Plot titles and axis labels must exactly match specified values (including version numbers like "- v2", "- v3").
#
# Use custom X-axis labels where required (e.g., 'Product 1', 'Product 2', ...).
#
# Apply gridlines and legends as specified per plot.
#
# Use styling (color, marker, linestyle) to distinguish data series in multi-line plots.
#
# All code should be organized in separate cells and run independently.
#
#
#
# Checklist
#
# Approach Level 1:
