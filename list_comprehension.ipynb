# %%
def max_words_in_sentences(sentences):
    return max(len(sentences.split) for sentence in sentences)

# %% [markdown]
# def max_words_in_sentences(sentences):

# %% [markdown]
# ## Concept Recap
# ### A list comprehension in Python is a concise way to create lists based on existing iterables. It allows for an easy and readable syntax to generate new lists by applying an expression to each item in the iterable and can include an optional condition to filter items. For example, if you have a list of integers and want to create a new list that contains only the even numbers, you could do so with a list comprehension like this:

# %%
def filter_strings_by_length(lst,n):
    return  [word for word in lst if len(word) > n]
